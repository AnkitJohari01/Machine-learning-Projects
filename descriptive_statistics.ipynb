# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Country.csv')

# %%
df
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# ...

# %%
df.isnull().sum()
# Out:
# country                                                       0
# Region                                                        0
# Surface area (km2)                                            0
# Population in thousands (2017)                                0
# Population density (per km2, 2017)                            0
# Sex ratio (m per 100 f, 2017)                                 0
# GDP: Gross domestic product (million current US$)             0
# GDP growth rate (annual %, const. 2005 prices)                0
# GDP per capita (current US$)                                  0
# Economy: Agriculture (% of GVA)                               0
# Economy: Industry (% of GVA)                                  0
# Economy: Services and other activity (% of GVA)               0
# Employment: Agriculture (% of employed)                       0
# Employment: Industry (% of employed)                          0
# Employment: Services (% of employed)                          0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# I want to find average population of all countries in year 2017

# %%
df["Population in thousands (2017)"].mean()
# Out:
# 32756.794759825327

# %%
# I want to find out the middle value of population of all 229 countries

# %%
df["Population in thousands (2017)"].median()
# Out:
# 5448.0

# %%
# most common population of all countries

# %%
df["Population in thousands (2017)"].mode()
# Out:
# 0        1
# 1       11
# 2       35
# 3       55
# 4       56
# 5      105
# 6      108
# 7      276
# 8      283
# 9     2890
# 10    2930
# Name: Population in thousands (2017), dtype: int64

# %%
# how to select random samplefrom population data then compare it with full data

# %%
# population = fulldata

df["Population in thousands (2017)"]
# Out:
# 0      35530
# 1       2930
# 2      41318
# 3         56
# 4         77
#        ...
# 224       12
# 225      553
# 226    28250
# 227    17094
# 228    16530
# Name: Population in thousands (2017), Length: 229, dtype: int64

# %%
sample_size = 100
sample_data = df.sample(n = sample_size,random_state = 1)

# %%
sample_data
# Out:
#                       country          Region Surface area (km2)  \
# 39   Central African Republic    MiddleAfrica             622984
# 170     Saint Kitts and Nevis       Caribbean                261
# 93                    Hungary   EasternEurope              93024
# 62                      Egypt  NorthernAfrica            1002000
# 199                Tajikistan     CentralAsia             142600
# ..                        ...             ...                ...
# 127                Martinique       Caribbean               1128
# 120                Madagascar   EasternAfrica             587295
# 54                    Czechia   EasternEurope              78868
# 118                 Lithuania  NorthernEurope              65286
# 98                       Iraq     WesternAsia             435052
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 39                             4659                                 7.5
# ...

# %%
sample_data["Population in thousands (2017)"]
# Out:
# 39      4659
# 170       55
# 93      9722
# 62     97553
# 199     8921
#        ...
# 127      385
# 120    25571
# 54     10618
# 118     2890
# 98     38275
# Name: Population in thousands (2017), Length: 100, dtype: int64

# %%
mean_sample = sample_data["Population in thousands (2017)"].mean()
mean_population = df['Population in thousands (2017)'].mean()

# %%
mean_sample
# Out:
# 34919.2

# %%
mean_population
# Out:
# 32756.794759825327

# %%
data = pd.read_csv('/content/housing.csv')

# %%
data
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
# What is the average price of houses with 3 bedrooms

# %%
x = data[data['bedrooms'] == 3]

# %%
x
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# 6      1321400060  20140627T000000  257500         3       2.25         1715
# 7      2008000270  20150115T000000  291850         3       1.50         1060
# ...           ...              ...     ...       ...        ...          ...
# 21603  7852140040  20140825T000000  507250         3       2.50         2270
# 21604  9834201367  20150126T000000  429000         3       2.00         1490
# 21607  2997800021  20150219T000000  475000         3       2.50         1310
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21611   291310100  20150116T000000  400000         3       2.50         1600
#
# ...

# %%
y = x['price'].mean()

# %%
y
# Out:
# 466232.07949918567

# %%
# **q2. what is the mode of the number of floors in tha dataset?**

# %%
x = data['floors'].mode()

# %%
x
# Out:
# 0    1.0
# Name: floors, dtype: float64

# %%
# **what is the avg price of houses built after the year 2000**

# %%
x = data[data['yr_built'] > 2000]
y = x['price'].mean()
y
# Out:
# 615314.914776481

# %%
y = x['price'].median()

# %%
y
# Out:
# 500000.0

# %%
#avg of square footage living  with more than 2 floors

# %%
x = data[data['floors'] > 2]

# %%
y = x['sqft_living'].mean()

# %%
y
# Out:
# 2075.182864450128

# %%
#what is the avg house price with  3 bed rooms and built b/w the years 2000 to 2005

bedrooms = data[data['bedrooms'] == 3]

avg_2000_2005 = bedrooms[(bedrooms['yr_built'] >= 2000) & (bedrooms['yr_built'] <= 2005)]

# %%
price = avg_2000_2005['price'].mean()

# %%
price
# Out:
# 498235.334625323

# %%
# **median square footage of living space (sqft_living) for houses with more than
# 2 floors and waterfront view**

# %%
x = data[(data['floors'] > 2) & (data['waterfront'] == 1)]
y = x['sqft_living'].median()
y
# Out:
# 3180.0

# %%
what is the median price of houses with a grade greater than 7
and a lot size of more than 5000 sq ft

# %%
what is the avg number of bathrooms for houses loacated in the zipcode 98001
 and having a view score of 3 or more
