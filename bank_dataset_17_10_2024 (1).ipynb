# %%
# Logistic regression is used for binary classification problem
# , where is outcome variable is categorical and typically has two possible values
# (yes/no , 0/1)

# %%
# key - concepts
# 1. sigmoid function
# 2. log - odd ratio
# 3. Maximum Likelihood Estimator

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/bank-additional-full-1 (1) (1).csv', sep = ";")

# %%
df
# Out:
#         age        job  marital            education  default housing loan  \
# 0      56.0  housemaid  married             basic.4y       no      no   no
# 1      57.0   services  married          high.school  unknown      no   no
# 2      37.0   services  married          high.school       no     yes   no
# 3      40.0     admin.  married             basic.6y       no      no   no
# 4      56.0   services  married          high.school       no      no  yes
# ...     ...        ...      ...                  ...      ...     ...  ...
# 41194  74.0    retired  married  professional.course       no     yes   no
# 41195  74.0        NaN  married  professional.course       no     yes   no
# 41196  74.0    retired  married                  NaN       no     yes   no
# 41197   NaN        NaN      NaN                  NaN      NaN     NaN  NaN
# 41198  74.0    retired  married  professional.course       no     yes  NaN
#
# ...

# %%
df.shape
# Out:
# (41199, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41199 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41195 non-null  float64
#  1   job             41194 non-null  object
#  2   marital         41194 non-null  object
#  3   education       41194 non-null  object
#  4   default         41195 non-null  object
#  5   housing         41196 non-null  object
#  6   loan            41195 non-null  object
#  7   contact         41195 non-null  object
#  8   month           41196 non-null  object
#  9   day_of_week     41196 non-null  object
#  10  duration        41196 non-null  float64
#  11  campaign        41196 non-null  float64
#  12  pdays           41196 non-null  float64
#  13  previous        41196 non-null  float64
#  14  poutcome        41194 non-null  object
#  15  emp.var.rate    41196 non-null  float64
#  16  cons.price.idx  41195 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# age               4
# job               5
# marital           5
# education         5
# default           4
# housing           3
# loan              4
# contact           4
# month             3
# day_of_week       3
# duration          3
# campaign          3
# pdays             3
# previous          3
# poutcome          5
# emp.var.rate      3
# cons.price.idx    4
# cons.conf.idx     3
# euribor3m         3
# nr.employed       3
# y                 3
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 76

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#         age         job  marital            education  default housing loan  \
# 0      56.0   housemaid  married             basic.4y       no      no   no
# 1      57.0    services  married          high.school  unknown      no   no
# 2      37.0    services  married          high.school       no     yes   no
# 3      40.0      admin.  married             basic.6y       no      no   no
# 4      56.0    services  married          high.school       no      no  yes
# ...     ...         ...      ...                  ...      ...     ...  ...
# 41185  56.0     retired  married    university.degree       no     yes   no
# 41186  44.0  technician  married  professional.course       no      no   no
# 41187  74.0     retired  married  professional.course       no     yes   no
# 41193  94.0     retired  married  professional.course       no     yes   no
# 41194  74.0     retired  married  professional.course       no     yes   no
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 13

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# age               float64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration          float64
# campaign          float64
# pdays             float64
# previous          float64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  41177.000000  41177.000000  41177.000000  41177.000000  41177.000000
# mean      40.025111    258.315346      2.567890    962.465697      0.173033
# std       10.423948    259.302190      2.770286    186.934918      0.494975
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    180.000000      2.000000    999.000000      0.000000
# 75%       47.000000    319.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41177.000000    41177.000000   41177.000000  41177.000000  41177.000000
# mean       0.081893       93.575749     -40.503113      3.621230   5167.029929
# ...

# %%
df['y']
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
#         ...
# 41184     no
# 41185     no
# 41186    yes
# 41187     no
# 41193     no
# Name: y, Length: 41177, dtype: object

# %%
# yes -> 1 , no-> 0
df['y'] = np.where(df['y'] == 'yes',1,0)
df['y'] = df['y'].astype(str)

# %%
df.dtypes
# Out:
# age               float64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration          float64
# campaign          float64
# pdays             float64
# previous          float64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
col_list = list(df.columns)

# %%
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed',
#  'y']

# %%
# outlier

# %%
col_list.remove('y')

# %%
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %%
for i in col_list:
    if df[i].dtype != 'object':
        sns.boxplot(df[i])
        plt.xlabel(i)
        plt.show()

# %%
columns = ['age','duration', 'campaign', 'cons.conf.idx']
for column in columns:
  Q1 = df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  IQR = Q3 - Q1
  lower_fence = Q1 - 1.5*IQR
  upper_fence = Q3 + 1.5*IQR

  df = df[(df[column] >= lower_fence) & (df[column] <= upper_fence)]

# %%
for i in col_list:
    if df[i].dtype != 'object':
        sns.boxplot(df[i])
        plt.xlabel(i)
        plt.show()

# %%
df['previous'].value_counts()
# Out:
# previous
# 0.0    30349
# 1.0     3962
# 2.0      600
# 3.0      176
# 4.0       57
# 5.0       16
# 6.0        4
# 7.0        1
# Name: count, dtype: int64

# %%
col_list = []
for col in df.columns:
    if (df[col].dtype == "object"):
      col_list.append(col)

# %%
col_list
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome',
#  'y']

# %%
from sklearn.preprocessing import LabelEncoder
l1 = LabelEncoder()
for i in col_list:
    df[i] = l1.fit_transform(df[i])

# %%
df
# Out:
#         age  job  marital  education  default  housing  loan  contact  month  \
# 0      56.0    3        1          0        0        0     0        1      6
# 1      57.0    7        1          3        1        0     0        1      6
# 2      37.0    7        1          3        0        2     0        1      6
# 3      40.0    0        1          1        0        0     0        1      6
# 4      56.0    7        1          3        0        0     2        1      6
# ...     ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41181  37.0    0        1          6        0        2     0        0      7
# 41182  29.0   10        2          0        0        2     0        0      7
# 41184  46.0    1        1          5        0        0     0        0      7
# 41185  56.0    5        1          6        0        2     0        0      7
# 41186  44.0    9        1          5        0        0     0        0      7
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35165 entries, 0 to 41186
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             35165 non-null  float64
#  1   job             35165 non-null  int64
#  2   marital         35165 non-null  int64
#  3   education       35165 non-null  int64
#  4   default         35165 non-null  int64
#  5   housing         35165 non-null  int64
#  6   loan            35165 non-null  int64
#  7   contact         35165 non-null  int64
#  8   month           35165 non-null  int64
#  9   day_of_week     35165 non-null  int64
#  10  duration        35165 non-null  float64
#  11  campaign        35165 non-null  float64
#  12  pdays           35165 non-null  float64
#  13  previous        35165 non-null  float64
#  14  poutcome        35165 non-null  int64
#  15  emp.var.rate    35165 non-null  float64
#  16  cons.price.idx  35165 non-null  float64
# ...

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr(),annot = True)
# Out:
# <Axes: >

# %%
#vif = 1/1-r2

# %%
# age - dependent varible
# all others except target are independent variable


# y = b1(pdays) + b2(education )-----

# r2

# vif = 1 / 1-r2

# %%
# 1 < vif < 5 moderate correlate
# 1 = no correlation
# vif > 5 - high correlation

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in df.columns:
    if ((df[col].dtype != 'object') & (col != 'y')):
      col_list.append(col)


X  = df[col_list]
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#            feature           VIF
# 0              age     22.113993
# 1              job      2.100861
# 2          marital      5.690071
# 3        education      4.560285
# 4          default      1.411946
# 5          housing      2.212409
# 6             loan      1.208306
# 7          contact      2.942422
# 8            month      6.685085
# 9      day_of_week      3.099808
# 10        duration      3.231026
# 11        campaign      3.615256
# 12           pdays    174.895512
# 13        previous      6.070087
# 14        poutcome     34.934345
# 15    emp.var.rate     37.592081
# 16  cons.price.idx  37885.320838
# 17   cons.conf.idx    143.576459
# 18       euribor3m    322.672944
# 19     nr.employed  43115.201160

# %%
X
# Out:
#         age  job  marital  education  default  housing  loan  contact  month  \
# 0      56.0    3        1          0        0        0     0        1      6
# 1      57.0    7        1          3        1        0     0        1      6
# 2      37.0    7        1          3        0        2     0        1      6
# 3      40.0    0        1          1        0        0     0        1      6
# 4      56.0    7        1          3        0        0     2        1      6
# ...     ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41181  37.0    0        1          6        0        2     0        0      7
# 41182  29.0   10        2          0        0        2     0        0      7
# 41184  46.0    1        1          5        0        0     0        0      7
# 41185  56.0    5        1          6        0        2     0        0      7
# 41186  44.0    9        1          5        0        0     0        0      7
#
# ...

# %%
df = df.drop(['nr.employed'],axis = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in df.columns:
    if ((df[col].dtype != 'object') & (col != 'y')):
      col_list.append(col)


X  = df[col_list]
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#            feature         VIF
# 0              age   22.107715
# 1              job    2.100612
# 2          marital    5.689362
# 3        education    4.558657
# 4          default    1.409350
# 5          housing    2.212084
# 6             loan    1.208260
# 7          contact    2.446094
# 8            month    5.784547
# 9      day_of_week    3.098930
# 10        duration    3.221277
# 11        campaign    3.602129
# 12           pdays  174.850562
# 13        previous    5.973295
# 14        poutcome   34.669168
# 15    emp.var.rate   22.287122
# 16  cons.price.idx  729.560618
# 17   cons.conf.idx  124.902304
# 18       euribor3m  130.883838

# %%
df = df.drop(['cons.price.idx'],axis = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in df.columns:
    if ((df[col].dtype != 'object') & (col != 'y')):
      col_list.append(col)


X  = df[col_list]
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#           feature        VIF
# 0             age  20.980560
# 1             job   2.095040
# 2         marital   5.544426
# 3       education   4.503309
# 4         default   1.409322
# 5         housing   2.210417
# 6            loan   1.207694
# 7         contact   2.348235
# 8           month   5.726141
# 9     day_of_week   3.084650
# 10       duration   3.196457
# 11       campaign   3.585901
# 12          pdays  95.504094
# 13       previous   3.040971
# 14       poutcome  17.519163
# 15   emp.var.rate  16.710516
# 16  cons.conf.idx  82.695453
# 17      euribor3m  93.815501

# %%
df = df.drop(['pdays'],axis = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in df.columns:
    if ((df[col].dtype != 'object') & (col != 'y')):
      col_list.append(col)


X  = df[col_list]
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#           feature        VIF
# 0             age  20.156176
# 1             job   2.091851
# 2         marital   5.426164
# 3       education   4.449798
# 4         default   1.409226
# 5         housing   2.206690
# 6            loan   1.207556
# 7         contact   2.274814
# 8           month   5.664673
# 9     day_of_week   3.072542
# 10       duration   3.184520
# 11       campaign   3.566503
# 12       previous   1.497582
# 13       poutcome   8.132807
# 14   emp.var.rate  12.914012
# 15  cons.conf.idx  42.662876
# 16      euribor3m  63.941291

# %%
df = df.drop(['euribor3m'],axis = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in df.columns:
    if ((df[col].dtype != 'object') & (col != 'y')):
      col_list.append(col)


X  = df[col_list]
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#           feature        VIF
# 0             age  17.204219
# 1             job   2.085747
# 2         marital   5.226350
# 3       education   4.292137
# 4         default   1.408832
# 5         housing   2.198757
# 6            loan   1.207316
# 7         contact   2.266725
# 8           month   5.270616
# 9     day_of_week   3.032416
# 10       duration   3.177169
# 11       campaign   3.560596
# 12       previous   1.479792
# 13       poutcome   8.004800
# 14   emp.var.rate   1.547619
# 15  cons.conf.idx  32.081295

# %%
df = df.drop(['cons.conf.idx'],axis =1 )

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in df.columns:
    if ((df[col].dtype != 'object') & (col != 'y')):
      col_list.append(col)


X  = df[col_list]
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#          feature        VIF
# 0            age  11.058997
# 1            job   2.076503
# 2        marital   4.372058
# 3      education   4.193335
# 4        default   1.407850
# 5        housing   2.162435
# 6           loan   1.204070
# 7        contact   2.242675
# 8          month   4.871672
# 9    day_of_week   2.969072
# 10      duration   3.105927
# 11      campaign   3.394175
# 12      previous   1.477225
# 13      poutcome   7.682693
# 14  emp.var.rate   1.532256

# %%
df = df.drop(['age'],axis =1 )

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in df.columns:
    if ((df[col].dtype != 'object') & (col != 'y')):
      col_list.append(col)


X  = df[col_list]
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#          feature       VIF
# 0            job  2.053348
# 1        marital  4.351772
# 2      education  4.013198
# 3        default  1.323133
# 4        housing  2.112544
# 5           loan  1.200876
# 6        contact  2.241469
# 7          month  4.605944
# 8    day_of_week  2.888478
# 9       duration  2.988925
# 10      campaign  3.194073
# 11      previous  1.442307
# 12      poutcome  6.538761
# 13  emp.var.rate  1.531336

# %%
x = list(vif_data.feature)

# %%
x
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'previous',
#  'poutcome',
#  'emp.var.rate']

# %%
ind_feat = df.drop(columns = 'y')

# %%
ind_feat
# Out:
#        job  marital  education  default  housing  loan  contact  month  \
# 0        3        1          0        0        0     0        1      6
# 1        7        1          3        1        0     0        1      6
# 2        7        1          3        0        2     0        1      6
# 3        0        1          1        0        0     0        1      6
# 4        7        1          3        0        0     2        1      6
# ...    ...      ...        ...      ...      ...   ...      ...    ...
# 41181    0        1          6        0        2     0        0      7
# 41182   10        2          0        0        2     0        0      7
# 41184    1        1          5        0        0     0        0      7
# 41185    5        1          6        0        2     0        0      7
# 41186    9        1          5        0        0     0        0      7
#
#        day_of_week  duration  campaign  previous  poutcome  emp.var.rate
# ...

# %%
dep_feat = df['y']

# %%
dep_feat
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41181    1
# 41182    0
# 41184    0
# 41185    0
# 41186    1
# Name: y, Length: 35165, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()

# %%
x_train,x_test,y_train,y_test = train_test_split(ind_feat,dep_feat,train_size = 0.80,random_state = 0)

# %%
log_model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = log_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score , confusion_matrix

# %%
ac = accuracy_score(y_test,y_pred)

# %%
ac
# Out:
# 0.9291909569173894

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[6378,  123],
#        [ 375,  157]])

# %%
       1      0
1   tp        fn

0    fp        tn

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(y_test,y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      6501
#            1       0.56      0.30      0.39       532
#
#     accuracy                           0.93      7033
#    macro avg       0.75      0.64      0.67      7033
# weighted avg       0.92      0.93      0.92      7033

# %%
ac = tp + tn / tp + tn + fp + fn

ac =

# %%
(6378 + 157)/ (6378 + 157 + 123 + 375)
# Out:
# 0.9291909569173894

# %%
p -  tp / tp + fp

# %%
# Out:
# 376.0

# %%
r - tp / tp + fn

# %%
f1 score = 2 * p *r / p + r

# %%
model = LogisticRegression(penalty = 'l2', C = 0.5, max_iter = 200)

# %%
overftting -

loss function - (y - yi) square - 0

j(0) - loss(0) +

# %%
# # ridge is going to shrink the coefficients towards zero , but not exactly zero
# # it handles multicollinearity issue well
# usage - when you suspect that many columns contributions to the target variable ,
# but individual contribution is small- l2

# %%
# lasso - performing feature selection
# when you want less features
# set the coefficient to zero
